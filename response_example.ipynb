# %%
# Example of usage of response class

import utils
from gdt.missions.fermi.gbm.poshist import GbmPosHist

# import data
detectors = ['b0', 'b1', 'n0', 'n1', 'n2', 'n3', 'n4', 'n5', 'n6', 'n7', 'n8', 'n9', 'na', 'nb']
skyGrid = utils.SkyGrid(5)
spacecraft_frames = GbmPosHist.open('glg_poshist_all_170817_v01.fit').get_spacecraft_frame()
t0 = 524666469.44569993
templates_directory = './templates/GBM'

# get response
from response import ResponseGenerator
response = ResponseGenerator(detectors, skyGrid, spacecraft_frames, t0, templates_directory)
rsp = response.get(1.728, 2.240, earthmask=False)
